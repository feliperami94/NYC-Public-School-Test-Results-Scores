# %% [markdown]
# Every year, American high school students take SATs, which are standardized tests intended to measure literacy, numeracy, and writing skills. There are three sections - reading, math, and writing, each with a **maximum score of 800 points**. These tests are extremely important for students and colleges, as they play a pivotal role in the admissions process.
#
# Analyzing the performance of schools is important for a variety of stakeholders, including policy and education professionals, researchers, government, and even parents considering which school their children should attend.
#
# You have been provided with a dataset called `schools.csv`, which is previewed below.
#
# You have been tasked with answering three key questions about New York City (NYC) public school SAT performance.

# %%
# Re-run this cell 
import pandas as pd

# Read in the data
schools = pd.read_csv("schools.csv")

# Preview the data
schools.head()

# Start coding here...
best_math_schools = (schools[schools["average_math"] >= (800*0.8)])
best_math_schools = best_math_schools[['school_name','average_math']].sort_values('average_math', ascending=False)
#best_math_schools provide the filtered and ordered list of the top 10 schools with higher average math results

schools['total_SAT'] = schools['average_math'] + schools['average_reading'] + schools['average_writing']
top_10_schools_unfiltered = schools.iloc[0:11]
top_10_schools = top_10_schools_unfiltered[['school_name','total_SAT']].fillna(0).sort_values('total_SAT', ascending=False)
#top_10_schools lists the top 10 Schools with the highest SAT.


boroughs = schools.groupby('borough')['total_SAT'].agg(['count', 'mean', 'std']).round(2)
#value_counts = grouped['total_SAT'].value_counts()
#stats = grouped['total_SAT'].agg(['mean','std']).fillna(0)
#largest_std_dev = stats.join(value_counts, rsuffix='_count').sort_values('std')
#.fillna(0).sort_values('std', ascending=False)
#largest_std_dev = largest_std_dev.iloc[:1,:]
print(grouped)
# Out:
#                count         mean         std
# borough
# Bronx             98  1202.724490  150.393901
# Brooklyn         109  1230.256881  154.868427
# Manhattan         89  1340.134831  230.294140
# Queens            69  1345.478261  195.252899
# Staten Island     10  1439.000000  222.303596
